# %% [markdown]
# Tuple
#
# 1. a만 있으면 햇갈릴 수 있음 -> a = ( 1, ) comma를 찍어주는 것이 좋음
# 2. 동시 할당할때 갯수가 같아야 한다 // 다르면 에러가 난다
# 3. def x() : return 1,2 =  type은 tuple , return 값은 오직 하나만 반환
#
# List
#
# 1. list는 출력할 때 수직적으로 출력함
#    문
#    근
#    영
# 2. Append와 extend의 차이
#    Append = element로 추가
#    Extend = list로 추가
#
#    l.append를 return 하면 NONE 값이 나오고 그 다음에 append된다는 특징을 지님
#
#    def s(t,L=[]) :
#     L.append(t) => 계속해서 t가 append한다 ?
#
#    공통점 : 결과값이 바로 나오지 않는다 ex.) a를 찍지 않으면 나오지 않는다
#
# TUPLE과 LIST
#
# 1. TUPLE - LIST = 수정할 수 있는 method가 나와서 LIST = mutable , tuple = immutable
# 2. Tuple – immutable 과 list – mutable (둘 다 heterogeneous, sequence type)
# 3.
#
# INDEX vs Count
#
# 1. 원소값을 넣으면 해당 원소의 index가 나온다 ( 0 부터 시작 )
# 2. Count는 몇번째 원소인지를 count ( 1 부터 시작 )
#
# Mutable
#
# 1. SET과 FROZEN SET 증명
# 2. Mutable -> 데이터 값이 변경이 가능한 거, 첫 번째 주소는 바뀌지 않는다 , 단 memory는 바뀐다
#
# 할당문
#
# 1. 숫자
# 2. 문자
#
# POP
# 1. ( 1,2,3,'문근영' ) => 마지막인 '문근영'을 빼준다 ( last in last out )
# 2. a.pop은 pop한것만 출력된다.
# 3. 다시 a를 치면 (1,2,3)만 출력된다.
#
#
# SET 연산자
#
# 1. Set는 연산자를 별도로 지원한다
# 2. 덧셈을 하면 뒤에 붙어지고, 곱셈은 반복
# 3. + 표시가 없어도 '문자열'일 경우 자동으로 합쳐진다
# 4. Set - mutable & Frozen Set -> list이지만 immutable
#
# 할당의 4가지 방식
#
# A = 1 , ( a , b = 1 , 2 ) , * 할당, a = b = 1
#
#
# Camel식 표기와 pascal식 표기
#
# SWAP
# 1. temp를 이용한 swap 방법
#
#
# DICTONARY
#
# 1. 공집합 안되고
# 2. view할때의 문법
# 3. 숫자는 KEY로 올 수 있다
# 4. TUPLE도 Key가 가능 : 대신 연산자 우선 순위 때문에 ()쳐야지 tuple로 인식, 기준을 명확하게 할 필요성이 있음
# 5. Key값은 immutable만 올 수 있다.
# 6. value 값은 모든 것이 올 수 있다 -> hetrogenious container
# 7. 집합은 내부적으로 순서를 정리하지만 dictonary는 orderedDict libary를 이용 필요
# 8. For문에서 default는 key값을 출력한다
#
# IN => 오른쪽과 왼쪽과 TYPE을 맞춰야 한다 (homogenious여야 한다) (질문이 필요)
#
#
# VIEW 문법의 3가지
# 1. Key
# 2. Values
# 3. Items
#
# Key error 방지
#
# 1. from collections import defaultdict => key값이 없으면 무조건 default를 반환
#
# 2. X['C']  key값이 없어서 key error
#    X.get('x',3)는 key error를 방지할 수 있음 (오류 방지용) => 뒤에 아무것을 넣어도 반환함
#
#
# Contianer
#
# 1. Heterogeneous : 서로 다른 데이터 타입의 모임
# 2. Homogeneous : 같은 데이터 타입의 모임
# 3. Sequence Type: 순서가 중요하고 , indexing 및 Slicing을 지원한다

# %%
**7개 별표 (드레곤볼)

1. 할당
    a, *b = a에 하나의 인수를 할당 나머지는 b에 할당
    a, *b , c 
    *a = 1,2,3,4,5,6 에러가 난다
    *a, : Tuple을 list로 변환시킨다
