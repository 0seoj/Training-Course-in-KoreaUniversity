# %% [markdown]
# # pandas (분석 관점)

# %%
import pandas as pd

# %%
# !pip install version-information
# Out:
# ...
#   Stored in directory: /Users/jung-yeongseo/Library/Caches/pip/wheels/1f/4c/b3/1976ac11dbd802723b564de1acaa453a72c36c95827e576321
# Successfully built version-information
# ...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
#load : 추가 매직메소드를 사용하겠다

# %%
# %load_ext version_information

# %%
# %version_information numpy,pandas
#버전 맨처음에 박아놓고 시작
# Out:
# Software versions
# Python 3.7.3 64bit [Clang 4.0.1 (tags/RELEASE_401/final)]
# IPython 7.4.0
# OS Darwin 18.0.0 x86_64 i386 64bit
# numpy 1.16.2
# pandas 0.24.2
# Tue Jul 23 12:14:31 2019 KST

# %%
# !pip install watermark

# %%
# %load_ext watermark

# %%
# %watermark -a'정영서' -d -p numpy,pandas  #누가만든지 알 수있음, 콤마뒤에 공백 있으면 안됨
# Out:
# UsageError: unrecognized arguments: #누가만든지 알 수있음, 콤마뒤에 공백 있으면 안됨

# %%
#즉, 버전확인하기위해
#분석 시작할때 watermark, version_information 써놓고 시작

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header=None)
#local도 가져올 수 있지만 웹에서도 가져올 수 있음
#데이터불러올때 엄청 개판인 데이터들은 option으로 체크하삼
#header=None으로하면 자동적으로 이름붙여줌

# %%
data[0]
#key방식 써야돼
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: 0, Length: 150, dtype: float64

# %%
# %matplotlib inline

# %% [markdown]
# ### 기본적인 데이터탐색을 해보자

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b737940>,
# ...
#       dtype=object)

# %%
data.mean()
# Out:
# 0    5.843333
# 1    3.054000
# 2    3.758667
# 3    1.198667
# dtype: float64

# %%
#데이터가 잘 불러왔는지 확인한 후 해야하는 일 (암기해)

# %%
#첫번째
data.info() 
#이걸로 알 수 있는것?
#rangeIndex : 인덱스를 따로 지정하지 않았다, 0부터 149까짖
#즉 전체 행 갯수
#column 갯수 알 수 있음

#누락된 데이터 :missing data -> 처리방법세가지 :삭제한다, 특별한수를 채워넣는다, 
#다행이 여긴 150개씩 다 갖져왔어. 미싱뎅터 없음
#다섯번째 컬럼은 object로되어잇음. (object = 문자열)

#메모리 사용량
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
#두번째
data.describe()
#각 컬럼에대한 통계값을 보여줒ㅁ
#size는 미싱데이터를 포함한 크기
#count는 미싱데이터를 포함하지 않은 크기

#정규성, boxplot을 알 수 있다.
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#중심극한정리 : 숫자가 커지면 중심에 가까워진다.

# %%
#숫자보다 그림으로 보는게편해
data.boxplot()

# %%
data.describe(include='object')
# Out:
#                   4
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
data.describe(include='all')
# 다볼수는 있는데 이쁘진않음. NaN이 미싱데이터
#
# Out:
#                  0           1           2           3            4
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
data.describe(include='float64') #보고싶은 타입만 볼 수 있따
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
import seaborn as sns 
#판다스 기반으로 통계적 그래프를 그려주는 애

# %%
sns.pairplot(data)
