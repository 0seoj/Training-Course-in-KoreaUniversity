# %%
import json

# %%
name = ("Kim", "Lee", "Park")
age = [30, 20, 10]
person = {"name": "Kim", "age":30, "car":False}

# %%
nameStr = json.dumps(name)
ageStr = json.dumps(age)
personStr = json.dumps(person, indent="  ")
print(personStr)
# Out:
# {
#   "name": "Kim",
#   "age": 30,
#   "car": false
# }

# %%
kname = ("김", "이", "박")
knameStr = json.dumps(kname)
print(knameStr)

knameStr = json.dumps(kname, ensure_ascii=False)
print(knameStr)
# Out:
# ["\uae40", "\uc774", "\ubc15"]
# ["김", "이", "박"]

# %%
personObj = json.loads(personStr) 
person == personObj
# Out:
# True

# %%
person["car"] = ["레이", "모닝"]

with open("person.json", "w") as f:
    json.dump(person, f)

# %%
with open("person.json", "r") as f:
    personObj = json.load(f)
    
personObj
# Out:
# {'name': 'Kim', 'age': 30, 'car': ['레이', '모닝']}

# %%
import json
import urllib.request

url = "http://ip.jsontest.com"

obj = {"name":"김이박"}

# %%
import urllib
import json
#url = "http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureSidoLIst?serviceKey=z%2BlyT2D1Vsb84cYXtpWei5P%2F3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q%3D%3D&numOfRows=10&pageNo=1&sidoName=%EC%84%9C%EC%9A%B8&searchCondition=DAILY"
#url = "http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?serviceKey=z%2BlyT2D1Vsb84cYXtpWei5P%2F3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q%3D%3D&numOfRows=10&pageNo=1&stationName=%EC%A2%85%EB%A1%9C%EA%B5%AC&dataTerm=DAILY&ver=1.3"

url = "http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty"
params = {
    "serviceKey" : "z%2BlyT2D1Vsb84cYXtpWei5P%2F3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q%3D%3D",
    "numOfRows" : 10,
    "pageSize" : 10,
    #"sidoName" : "서울",
    #"searchCondition" : "DAILY",
    "pageNo" : 1,
    "startPage":1,
    "stationName":"종로구",
    "dataTerm": "DAILY",
    "ver":"1.3",
    "_returnType":"JSON"
}

params["serviceKey"] = urllib.parse.unquote(params["serviceKey"])
params = urllib.parse.urlencode(params)   #파이썬의 딕셔너리 형태를 스트링으로 바꿔줌
params = params.encode("utf-8") #스트링을 바이트형태로 넘겨줌

req = urllib.request.Request(url, data=params) #파라메터는 무조건 바이트로 넘겨야한다!
res = urllib.request.urlopen(req)

resStr = res.read()

resStr = resStr.decode("utf-8") #바이트로넘긴 값을 해석하기위해 스트링으로 바꿔줌
resObj = json.loads(resStr) #스트링을 파이썬의 딕셔너리 형태로 바꿔줌
resJSON = json.dumps(resObj, indent =" ", ensure_ascii = False)
print(resJSON)
# Out:
# {
#  "list": [
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 14:00",
#    "khaiGrade": "2",
#    "khaiValue": "51",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.012",
#    "numOfRows": "10",
#    "o3Grade": "2",
#    "o3Value": "0.031",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "13",
#    "pm10Value24": "11",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "7",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.002",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 13:00",
#    "khaiGrade": "2",
#    "khaiValue": "53",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.009",
#    "numOfRows": "10",
#    "o3Grade": "2",
#    "o3Value": "0.033",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "11",
#    "pm10Value24": "11",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "5",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.002",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 12:00",
#    "khaiGrade": "2",
#    "khaiValue": "51",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.011",
#    "numOfRows": "10",
#    "o3Grade": "2",
#    "o3Value": "0.031",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "12",
#    "pm10Value24": "11",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "6",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.4",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 11:00",
#    "khaiGrade": "1",
#    "khaiValue": "45",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.015",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.027",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "14",
#    "pm10Value24": "11",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "9",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 10:00",
#    "khaiGrade": "2",
#    "khaiValue": "52",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.010",
#    "numOfRows": "10",
#    "o3Grade": "2",
#    "o3Value": "0.032",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "11",
#    "pm10Value24": "9",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "6",
#    "pm25Value24": "5",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.4",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 09:00",
#    "khaiGrade": "1",
#    "khaiValue": "48",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.010",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.029",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "13",
#    "pm10Value24": "9",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "6",
#    "pm25Value24": "5",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 08:00",
#    "khaiGrade": "1",
#    "khaiValue": "47",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.009",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.028",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "9",
#    "pm10Value24": "8",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "4",
#    "pm25Value24": "5",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 07:00",
#    "khaiGrade": "1",
#    "khaiValue": "42",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.011",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.025",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "4",
#    "pm10Value24": "8",
#    "pm25Grade": "1",
#    "pm25Grade1h": "",
#    "pm25Value": "-",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.4",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 06:00",
#    "khaiGrade": "1",
#    "khaiValue": "42",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.009",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.025",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "7",
#    "pm10Value24": "9",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "5",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   },
#   {
#    "_returnType": "json",
#    "coGrade": "1",
#    "coValue": "0.3",
#    "dataTerm": "",
#    "dataTime": "2019-07-10 05:00",
#    "khaiGrade": "1",
#    "khaiValue": "42",
#    "mangName": "도시대기",
#    "no2Grade": "1",
#    "no2Value": "0.008",
#    "numOfRows": "10",
#    "o3Grade": "1",
#    "o3Value": "0.025",
#    "pageNo": "1",
#    "pm10Grade": "1",
#    "pm10Grade1h": "1",
#    "pm10Value": "6",
#    "pm10Value24": "10",
#    "pm25Grade": "1",
#    "pm25Grade1h": "1",
#    "pm25Value": "4",
#    "pm25Value24": "6",
#    "resultCode": "",
#    "resultMsg": "",
#    "rnum": 0,
#    "serviceKey": "",
#    "sidoName": "",
#    "so2Grade": "1",
#    "so2Value": "0.003",
#    "stationCode": "",
#    "stationName": "",
#    "totalCount": "",
#    "ver": ""
#   }
#  ],
#  "parm": {
#   "_returnType": "json",
#   "coGrade": "",
#   "coValue": "",
#   "dataTerm": "DAILY",
#   "dataTime": "",
#   "khaiGrade": "",
#   "khaiValue": "",
#   "mangName": "",
#   "no2Grade": "",
#   "no2Value": "",
#   "numOfRows": "10",
#   "o3Grade": "",
#   "o3Value": "",
#   "pageNo": "1",
#   "pm10Grade": "",
#   "pm10Grade1h": "",
#   "pm10Value": "",
#   "pm10Value24": "",
#   "pm25Grade": "",
#   "pm25Grade1h": "",
#   "pm25Value": "",
#   "pm25Value24": "",
#   "resultCode": "",
#   "resultMsg": "",
#   "rnum": 0,
#   "serviceKey": "z+lyT2D1Vsb84cYXtpWei5P/3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q==",
#   "sidoName": "",
#   "so2Grade": "",
#   "so2Value": "",
#   "stationCode": "",
#   "stationName": "종로구",
#   "totalCount": "",
#   "ver": "1.3"
#  },
#  "ArpltnInforInqireSvcVo": {
#   "_returnType": "json",
#   "coGrade": "",
#   "coValue": "",
#   "dataTerm": "DAILY",
#   "dataTime": "",
#   "khaiGrade": "",
#   "khaiValue": "",
#   "mangName": "",
#   "no2Grade": "",
#   "no2Value": "",
#   "numOfRows": "10",
#   "o3Grade": "",
#   "o3Value": "",
#   "pageNo": "1",
#   "pm10Grade": "",
#   "pm10Grade1h": "",
#   "pm10Value": "",
#   "pm10Value24": "",
#   "pm25Grade": "",
#   "pm25Grade1h": "",
#   "pm25Value": "",
#   "pm25Value24": "",
#   "resultCode": "",
#   "resultMsg": "",
#   "rnum": 0,
#   "serviceKey": "z+lyT2D1Vsb84cYXtpWei5P/3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q==",
#   "sidoName": "",
#   "so2Grade": "",
#   "so2Value": "",
#   "stationCode": "",
#   "stationName": "종로구",
#   "totalCount": "",
#   "ver": "1.3"
#  },
#  "totalCount": 23
# }

# %%
resObj.keys()
# Out:
# dict_keys(['list', 'parm', 'ArpltnInforInqireSvcVo', 'totalCount'])

# %%
type(resObj)
# Out:
# dict

# %%
resObj.keys()
# Out:
# dict_keys(['list', 'parm', 'ArpltnInforInqireSvcVo', 'totalCount'])

# %%
resObj["list"][0]["pm25Value"]
#resObj["list"][0]["stationName"]
# Out:
# '6'

# %%
resObj["list"][0]["stationName"]
# Out:
# ''

# %%
#xml

import xml.etree.ElementTree as et
from lxml import etree

# %%
bookStore = et.Element("bookstore")

# %%
book1 = et.Element("book", caftegory="cooking")
bookStore.insert(0, book1)

# %%
#노드 만들어서 붙이는 과정
title1 = et.Element("title")
title1.attrib["lang"] = "en"
title1.text = "Everyday Italian"
book1.append(title1)

# %%
#subelement 붙이는 과정
et.SubElement(book1, "author").text = "Giada De Laurentils"
et.SubElement(book1, "year").text = "2005"
et.SubElement(book1, "price").text = "30.00"

# %%
book2 = et.Element("book", {"category":"children"})
bookStore.append(book2)

# %%
title2 = et.Element("title")
title2.attrib["lang"]=title1.get("lang")
title2.text = "Harry Potter"
book2.append(title2)

# %%
et.SubElement(book2, "author").text = "Giada De Laurentiils"
et.SubElement(book2, "year").text = "2005"
et.SubElement(book2, "price").text = "30.00"

# %%
et.dump(bookStore)
# Out:
# <bookstore><book caftegory="cooking"><title lang="en">Everyday Italian</title><author>Giada De Laurentils</author><year>2005</year><price>30.00</price></book><book category="children"><title lang="en">Harry Potter</title><author>Giada De Laurentiils</author><year>2005</year><price>30.00</price></book></bookstore>

# %%
root = et.fromstring(et.tostring(bookStore))

# %%
from xml.etree.ElementTree import ElementTree

tree = ElementTree(root)
tree.write("book_xml.xml", encoding="utf-8", xml_declaration="utf-8")

# %%
from xml.etree.ElementTree import parse

tree = parse("book_xml.xml")
root = tree.getroot()

for node in root.iter():
    print(node.tag, node.text)
# Out:
# bookstore None
# book None
# title Everyday Italian
# author Giada De Laurentils
# year 2005
# price 30.00
# book None
# title Harry Potter
# author Giada De Laurentiils
# year 2005
# price 30.00

# %%
#lxml

bookStore = etree.Element("bookstore")

book1 = etree.SubElement(bookStore, "book")
book2 = etree.SubElement(bookStore, "book", attrib={"category":"children"})

book1.attrib["category"] = "cooking"

title1 = etree.Element("title", lang="en")
title1.text = "Everyday Italian"
book1.append(title1)

etree.SubElement(book1, "author").text = "Giada De Laurentils"
etree.SubElement(book1, "year").text = "2005"
etree.SubElement(book1, "price").text = "30.00"

title2 = etree.Element("title")
title2.set("lang", title1.get("lang"))
title2.text = "Harry Potter"
book2.append(title2)

etree.SubElement(book2, "author").text = "Giada De Laurentiils"
etree.SubElement(book2, "year").text = "2005"
book2.insert(3, etree.Element("price"))

print(len(book2))
book2[-1].text = "30.00"

xmlBytes = etree.tostring(bookStore, encoding="utf-8", pretty_print=True, xml_declaration=True)
xmlStr = etree.tounicode(bookStore, pretty_print=True)
print(type(xmlBytes), type(xmlStr))
etree.dump(bookStore)
# Out:
# 4
# <class 'bytes'> <class 'str'>
# <bookstore>
#   <book category="cooking">
#     <title lang="en">Everyday Italian</title>
#     <author>Giada De Laurentils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
#   <book category="children">
#     <title lang="en">Harry Potter</title>
#     <author>Giada De Laurentiils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
# </bookstore>

# %%
xml = etree.XML(etree.tostring(bookStore))
xmlTree = etree.ElementTree(xml)
xmlRoot = xmlTree.getroot()

print(xmlTree.docinfo.xml_version)
print(xmlTree.docinfo.encoding)
print(xmlTree.docinfo.doctype)
print(xmlTree.docinfo.root_name)

print(len(xmlRoot))
for childNode in xmlRoot:
    print(childNode.tag, childNode.attrib)
# Out:
# 1.0
# UTF-8
#
# bookstore
# 2
# book {'category': 'cooking'}
# book {'category': 'children'}

# %%
xmlTree.write("book_tree.xml")
etree.ElementTree(xmlRoot).write("book_root.xml")

# %%
xmlTree = etree.parse("book_tree.xml")
xmlRoot = xmlTree.getroot()

etree.dump(xmlRoot)

xmlTree = etree.parse("book_root.xml")
xmlRoot = xmlTree.getroot()

etree.dump(xmlRoot)
# Out:
# <bookstore>
#   <book category="cooking">
#     <title lang="en">Everyday Italian</title>
#     <author>Giada De Laurentils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
#   <book category="children">
#     <title lang="en">Harry Potter</title>
#     <author>Giada De Laurentiils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
# </bookstore>
# <bookstore>
#   <book category="cooking">
#     <title lang="en">Everyday Italian</title>
#     <author>Giada De Laurentils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
#   <book category="children">
#     <title lang="en">Harry Potter</title>
#     <author>Giada De Laurentiils</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
# </bookstore>

# %%
url = "http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureSidoLIst"

params = {
    "serviceKey":"z%2BlyT2D1Vsb84cYXtpWei5P%2F3nNiNCkckrE8sWLwhNhBD3Eq8nzyTuLC3GUVCBEDwvg9llPFT1tkNjn3PdoJ9Q%3D%3D",
    "numOfRows":10,
    #"pageSize":10,
    "pageNo":1,
    #"startPage":1,
    #"stationName":"성북구",
    #"dataTerm":"DAILY",
    #"ver":"1.3",
    "sidoName":'서울',
    "searchCondition" : "Daily"
    #"_returnType":"XML"
}
print(type(params))
params["serviceKey"] = urllib.parse.unquote(params["serviceKey"])
params = urllib.parse.urlencode(params)
print(type(params))
params = params.encode("utf-8")
print(type(params))
#params는 스트링값이다. 
req = urllib.request.Request(url, data=params)
print(type(req))
#request get 방식으로 처리한다. 
res = urllib.request.urlopen(req)
print(type(res))
resStr = res.read()

# resStr = resStr.decode("utf-8")
print(resStr)
# Out:
# <class 'dict'>
# <class 'str'>
# <class 'bytes'>
# <class 'urllib.request.Request'>
# <class 'http.client.HTTPResponse'>
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>00</resultCode>\r\n\t\t<resultMsg>NORMAL SERVICE.</resultMsg>\r\n\t</header>\r\n\t<body>\r\n\t\t<items>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb0\x95\xeb\x82\xa8\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.005</so2Value>\r\n\t\t\t\t    <coValue>0.2</coValue>\r\n\t\t\t\t    <o3Value>0.024</o3Value>\r\n\t\t\t\t    <no2Value>0.013</no2Value>\r\n\t\t\t\t    <pm10Value>14</pm10Value>\r\n\t\t\t\t    <pm25Value>7</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb0\x95\xeb\x8f\x99\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.003</so2Value>\r\n\t\t\t\t    <coValue>0.2</coValue>\r\n\t\t\t\t    <o3Value>0.029</o3Value>\r\n\t\t\t\t    <no2Value>0.009</no2Value>\r\n\t\t\t\t    <pm10Value>15</pm10Value>\r\n\t\t\t\t    <pm25Value>8</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb0\x95\xeb\xb6\x81\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>-</so2Value>\r\n\t\t\t\t    <coValue>0.2</coValue>\r\n\t\t\t\t    <o3Value>0.032</o3Value>\r\n\t\t\t\t    <no2Value>0.008</no2Value>\r\n\t\t\t\t    <pm10Value>13</pm10Value>\r\n\t\t\t\t    <pm25Value>6</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb0\x95\xec\x84\x9c\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.004</so2Value>\r\n\t\t\t\t    <coValue>0.3</coValue>\r\n\t\t\t\t    <o3Value>0.032</o3Value>\r\n\t\t\t\t    <no2Value>0.016</no2Value>\r\n\t\t\t\t    <pm10Value>12</pm10Value>\r\n\t\t\t\t    <pm25Value>7</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb4\x80\xec\x95\x85\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.003</so2Value>\r\n\t\t\t\t    <coValue>0.1</coValue>\r\n\t\t\t\t    <o3Value>0.035</o3Value>\r\n\t\t\t\t    <no2Value>0.013</no2Value>\r\n\t\t\t\t    <pm10Value>16</pm10Value>\r\n\t\t\t\t    <pm25Value>4</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb4\x91\xec\xa7\x84\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.003</so2Value>\r\n\t\t\t\t    <coValue>0.4</coValue>\r\n\t\t\t\t    <o3Value>0.026</o3Value>\r\n\t\t\t\t    <no2Value>0.012</no2Value>\r\n\t\t\t\t    <pm10Value>9</pm10Value>\r\n\t\t\t\t    <pm25Value>-</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb5\xac\xeb\xa1\x9c\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.004</so2Value>\r\n\t\t\t\t    <coValue>-</coValue>\r\n\t\t\t\t    <o3Value>0.035</o3Value>\r\n\t\t\t\t    <no2Value>0.011</no2Value>\r\n\t\t\t\t    <pm10Value>15</pm10Value>\r\n\t\t\t\t    <pm25Value>6</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>0.003</so2Value>\r\n\t\t\t\t    <coValue>0.2</coValue>\r\n\t\t\t\t    <o3Value>0.028</o3Value>\r\n\t\t\t\t    <no2Value>0.013</no2Value>\r\n\t\t\t\t    <pm10Value>17</pm10Value>\r\n\t\t\t\t    <pm25Value>7</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-07-10 16:00</dataTime>\r\n\t\t\t\t    <cityName>\xeb\x85\xb8\xec\x9b\x90\xea\xb5\xac</cityName>\r\n\t\t\t\t    <so2Value>-</so2Value>\r\n\t\t\t\t    <coValue>0.2</coValue>\r\n\t\t\t\t    <o3Value>0.028</o3Value>\r\n\t\t\t\t    <no2Value>0.009</no2Value>\r\n\t\t\t\t    <pm10Value>11</pm10Value>\r\n\t\t\t\t    <pm25Value>7</pm25Value>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t    <dataTime>2019-0 ...

# %%
xmlObj = etree.fromstring(resStr)
xmlRoot = etree.ElementTree(xmlObj).getroot()

etree.dump(xmlRoot)

for node in xmlRoot.iter():
    print(node.tag, node.text)
    
itemList = xmlRoot.findall(".//item")

print(len(itemList))
for item in itemList:
    for i in range(len(item)):
        print(item[i].tag, item[i].text)
        
pm25List = xmlRoot.findall(".//item/pm25Value")
for item in pm25List:
    print(item.tag, item.text)
# Out:
# <response>
# 	<header>
# 		<resultCode>00</resultCode>
# 		<resultMsg>NORMAL SERVICE.</resultMsg>
# 	</header>
# 	<body>
# 		<items>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>강남구</cityName>
# 				    <so2Value>0.005</so2Value>
# 				    <coValue>0.2</coValue>
# 				    <o3Value>0.024</o3Value>
# 				    <no2Value>0.013</no2Value>
# 				    <pm10Value>14</pm10Value>
# 				    <pm25Value>7</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>강동구</cityName>
# 				    <so2Value>0.003</so2Value>
# 				    <coValue>0.2</coValue>
# 				    <o3Value>0.029</o3Value>
# 				    <no2Value>0.009</no2Value>
# 				    <pm10Value>15</pm10Value>
# 				    <pm25Value>8</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>강북구</cityName>
# 				    <so2Value>-</so2Value>
# 				    <coValue>0.2</coValue>
# 				    <o3Value>0.032</o3Value>
# 				    <no2Value>0.008</no2Value>
# 				    <pm10Value>13</pm10Value>
# 				    <pm25Value>6</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>강서구</cityName>
# 				    <so2Value>0.004</so2Value>
# 				    <coValue>0.3</coValue>
# 				    <o3Value>0.032</o3Value>
# 				    <no2Value>0.016</no2Value>
# 				    <pm10Value>12</pm10Value>
# 				    <pm25Value>7</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>관악구</cityName>
# 				    <so2Value>0.003</so2Value>
# 				    <coValue>0.1</coValue>
# 				    <o3Value>0.035</o3Value>
# 				    <no2Value>0.013</no2Value>
# 				    <pm10Value>16</pm10Value>
# 				    <pm25Value>4</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>광진구</cityName>
# 				    <so2Value>0.003</so2Value>
# 				    <coValue>0.4</coValue>
# 				    <o3Value>0.026</o3Value>
# 				    <no2Value>0.012</no2Value>
# 				    <pm10Value>9</pm10Value>
# 				    <pm25Value>-</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>구로구</cityName>
# 				    <so2Value>0.004</so2Value>
# 				    <coValue>-</coValue>
# 				    <o3Value>0.035</o3Value>
# 				    <no2Value>0.011</no2Value>
# 				    <pm10Value>15</pm10Value>
# 				    <pm25Value>6</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>금천구</cityName>
# 				    <so2Value>0.003</so2Value>
# 				    <coValue>0.2</coValue>
# 				    <o3Value>0.028</o3Value>
# 				    <no2Value>0.013</no2Value>
# 				    <pm10Value>17</pm10Value>
# 				    <pm25Value>7</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>노원구</cityName>
# 				    <so2Value>-</so2Value>
# 				    <coValue>0.2</coValue>
# 				    <o3Value>0.028</o3Value>
# 				    <no2Value>0.009</no2Value>
# 				    <pm10Value>11</pm10Value>
# 				    <pm25Value>7</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2019-07-10 16:00</dataTime>
# 				    <cityName>도봉구</cityName>
# 				    <so2Value>0.003</so2Value>
# 				    <coValue>0.3</coValue>
# 				    <o3Value>0.035</o3Value>
# 				    <no2Value>0.005</no2Value>
# 				    <pm10Value>11</pm10Value>
# 				    <pm25Value>4</pm25Value>
# 				</item>
#
# 		</items>
# 		<numOfRows>10</numOfRows>
#         <pageNo>1</pageNo>
#         <totalCount>625</totalCount>
# 	</body>
# </response>
# response
#
# header
#
# resultCode 00
# resultMsg NORMAL SERVICE.
# body
#
# items
#
#
# item
#
# dataTime 2019-07-10 16:00
# cityName 강남구
# so2Value 0.005
# coValue 0.2
# o3Value 0.024
# no2Value 0.013
# pm10Value 14
# pm25Value 7
# item
#
# dataTime 2019-07-10 16:00
# cityName 강동구
# so2Value 0.003
# coValue 0.2
# o3Value 0.029
# no2Value 0.009
# pm10Value 15
# pm25Value 8
# item
#
# dataTime 2019-07-10 16:00
# cityName 강북구
# so2Value -
# coValue 0.2
# o3Value 0.032
# no2Value 0.008
# pm10Value 13
# pm25Value 6
# item
#
# dataTime 2019-07-10 16:00
# cityName 강서구
# so2Value 0.004
# coValue 0.3
# o3Value 0.032
# no2Value 0.016
# pm10Value 12
# pm25Value 7
# item
#
# dataTime 2019-07-10 16:00
# cityName 관악구
# so2Value 0.003
# coValue 0.1
# o3Value 0.035
# no2Value 0.013
# pm10Value 16
# pm25Value 4
# item
#
# dataTime 2019-07-10 16:00
# cityName 광진구
# so2Value 0.003
# coValue 0.4
# o3Value 0.026
# no2Value 0.012
# pm10Value 9
# pm25Value -
# item
#
# dataTime 2019-07-10 16:00
# cityName 구로구
# so2Value 0.004
# coValue -
# o3Value 0.035
# no2Value 0.011
# pm10Value 15
# pm25Value 6
# item
#
# dataTime 2019-07-10 16:00
# cityName 금천구
# so2Value 0.003
# coValue 0.2
# o3Value 0.028
# no2Value 0.013
# pm10Value 17
# pm25Value 7
# item
#
# dataTime 2019-07-10 16:00
# cityName 노원구
# so2Value -
# coValue 0.2
# o3Value 0.028
# no2Value 0.009
# pm10Value 11
# pm25Value 7
# item
#
# dataTime 2019-07-10 16:00
# cityName 도봉구
# so2Value 0.003
# coValue 0.3
# o3Value 0.035
# no2Value 0.005
# pm10Value 11
# pm25Value 4
# numOfRows 10
# pageNo 1
# totalCount 625
# 10
# dataTime 2019-07-10 16:00
# cityName 강남구
# so2Value 0.005
# coValue 0.2
# o3Value 0.024
# no2Value 0.013
# pm10Value 14
# pm25Value 7
# dataTime 2019-07-10 16:00
# cityName 강동구
# so2Value 0.003
# coValue 0.2
# o3Value 0.029
# no2Value 0.009
# pm10Value 15
# pm25Value 8
# dataTime 2019-07-10 16:00
# cityName 강북구
# so2Value -
# coValue 0.2
# o3Value 0.032
# no2Value 0.008
# pm10Value 13
# pm25Value 6
# dataTime 2019-07-10 16:00
# cityName 강서구
# so2Value 0.004
# coValue 0.3
# o3Value 0.032
# no2Value 0.016
# pm10Value 12
# pm25Value 7
# dataTime 2019-07-10 16:00
# cityName 관악구
# so2Value 0.003
# coValue 0.1
# o3Value 0.035
# no2Value 0.013
# pm10Value 16
# pm25Value 4
# dataTime 2019-07-10 16:00
# cityName 광진구
# so2Value 0.003
# coValue 0.4
# o3Value 0.026
# no2Value 0.012
# pm10Value 9
# pm25Value -
# dataTime 2019-07-10 16:00
# cityName 구로구
# so2Value 0.004
# coValue -
# o3Value 0.035
# no2Value 0.011
# pm10Value 15
# pm25Value 6
# dataTime 2019-07-10 16:00
# cityName 금천구
# so2Value 0.003
# coValue 0.2
# o3Value 0.028
# no2Value 0.013
# pm10Value 17
# pm25Value 7
# dataTime 2019-07-10 16:00
# cityName 노원구
# so2Value -
# coValue 0.2
# o3Value 0.028
# no2Value 0.009
# pm10Value 11
# pm25Value 7
# dataTime 2019-07-10 16:00
# cityName 도봉구
# so2Value 0.003
# coValue 0.3
# o3Value 0.035
# no2Value 0.005
# pm10Value 11
# pm25Value 4
# pm25Value 7
# pm25Value 8
# pm25Value 6
# pm25Value 7
# pm25Value 4
# pm25Value -
# pm25Value 6
# pm25Value 7
# pm25Value 7
# pm25Value 4
